# %% [markdown]
# # 1. Import Dependencies

# %%
import gym 
from stable_baselines3 import A2C
from stable_baselines3.common.vec_env import VecFrameStack
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_util import make_atari_env
import os

# %% [markdown]
# # 2. Test Environment

# %%
environment_name = "Breakout-v0"

# %%
env = gym.make(environment_name)

# %%
episodes = 5
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0 
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score+=reward
    print('Episode:{} Score:{}'.format(episode, score))
env.close()
# Out:
# 2022-09-11 19:43:12.962 python[84410:35101667] Warning: Expected min height of view: (<NSPopoverTouchBarItemButton: 0x7fb79385f7c0>) to be less than or equal to 30 but got a height of 32.000000. This error will be logged once per view in violation.
# 2022-09-11 19:43:12.963 python[84410:35101667] Warning: Expected min height of view: (<NSButton: 0x7fb796421540>) to be less than or equal to 30 but got a height of 32.000000. This error will be logged once per view in violation.
# 2022-09-11 19:43:12.965 python[84410:35101667] Warning: Expected min height of view: (<NSPopoverTouchBarItemButton: 0x7fb7964221b0>) to be less than or equal to 30 but got a height of 32.000000. This error will be logged once per view in violation.
# 2022-09-11 19:43:12.967 python[84410:35101667] Warning: Expected min height of view: (<NSPopoverTouchBarItemButton: 0x7fb796424410>) to be less than or equal to 30 but got a height of 32.000000. This error will be logged once per view in violation.
# Episode:1 Score:1.0
# Episode:2 Score:1.0
# Episode:3 Score:1.0
# Episode:4 Score:2.0
# Episode:5 Score:1.0

# %%
env.action_space.sample()
# Out:
# 0

# %%
env.observation_space.sample()
# Out:
# array([[[  7,  79,   6],
#         [ 16, 151, 185],
#         [ 99, 194, 105],
#         ...,
#         [ 50,  23, 191],
#         [140, 130,  27],
#         [115,  39, 191]],
#
#        [[136,  75, 186],
#         [ 85, 206, 146],
#         [240,  13,  89],
#         ...,
#         [191, 210,  32],
#         [126, 130,  10],
#         [ 32, 154, 135]],
#
#        [[215, 157,  45],
#         [223,  15, 249],
#         [239,   2,  87],
#         ...,
#         [ 23, 132, 187],
#         [ 41, 145,  23],
#         [143, 212, 251]],
#
#        ...,
#
#        [[ 23,  92, 187],
#         [ 11, 254, 116],
#         [ 89,  79,   1],
#         ...,
#         [243,  24,  45],
#         [  0, 134, 223],
#         [ 25, 229, 224]],
#
#        [[ 88,  48, 152],
#         [237, 188,  29],
#         [144, 226, 229],
#         ...,
#         [ 77, 178, 120],
#         [ 43,  62, 162],
#         [194, 212, 130]],
#
#        [[135, 251, 110],
#         [116,  85,  44],
#         [214, 221, 129],
#         ...,
#         [255,  46, 171],
#         [244,   7,  51],
#         [ 37,  83, 106]]], dtype=uint8)

# %% [markdown]
# # 3. Vectorise Environment and Train Model

# %%
env = make_atari_env('Breakout-v0', n_envs=4, seed=0)

# %%
env = VecFrameStack(env, n_stack=4)

# %%
log_path = os.path.join('Training', 'Logs')

# %%
model = A2C("CnnPolicy", env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device
# Wrapping the env in a VecTransposeImage.

# %%
# !which tensorboard
# Out:
# /usr/local/anaconda3/envs/bmrl/bin/tensorboard

# %%
model.learn(total_timesteps=400000)
# Out:
# Logging to Training/Logs/A2C_1
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 266      |
# |    ep_rew_mean        | 1.19     |
# | time/                 |          |
# |    fps                | 267      |
# |    iterations         | 100      |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -1.39    |
# |    explained_variance | 0.106    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | 0.195    |
# |    value_loss         | 0.19     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 277      |
# |    ep_rew_mean        | 1.42     |
# | time/                 |          |
# |    fps                | 265      |
# |    iterations         | 200      |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -1.39    |
# |    explained_variance | -4.22    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | -0.227   |
# |    value_loss         | 0.0642   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 295      |
# |    ep_rew_mean        | 1.74     |
# | time/                 |          |
# |    fps                | 268      |
# |    iterations         | 300      |
# |    time_elapsed       | 22       |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -1.34    |
# |    explained_variance | 0.552    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | -0.0396  |
# |    value_loss         | 0.136    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 305      |
# |    ep_rew_mean        | 1.93     |
# | time/                 |          |
# |    fps                | 268      |
# |    iterations         | 400      |
# |    time_elapsed       | 29       |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -0.997   |
# |    explained_variance | 0.958    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | -0.0388  |
# |    value_loss         | 0.0166   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 312      |
# |    ep_rew_mean        | 2.05     |
# | time/                 |          |
# |    fps                | 267      |
# |    iterations         | 500      |
# |    time_elapsed       | 37       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -1.29    |
# |    explained_variance | 0.81     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | 0.0516   |
# |    value_loss         | 0.0729   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 316      |
# |    ep_rew_mean        | 2.15     |
# | time/                 |          |
# |    fps                | 267      |
# |    iterations         | 600      |
# |    time_elapsed       | 44       |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -1.15    |
# |    explained_variance | 0.922    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | -0.0512  |
# |    value_loss         | 0.0367   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 310      |
# |    ep_rew_mean        | 2.06     |
# | time/                 |          |
# |    fps                | 266      |
# |    iterations         | 700      |
# |    time_elapsed       | 52       |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -1.22    |
# |    explained_variance | 0.938    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | -0.0371  |
# |    value_loss         | 0.025    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 304      |
# |    ep_rew_mean        | 1.99     |
# | time/                 |          |
# |    fps                | 263      |
# |    iterations         | 800      |
# |    time_elapsed       | 60       |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -1.06    |
# |    explained_variance | 0.945    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | 0.0854   |
# |    value_loss         | 0.0697   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 300      |
# |    ep_rew_mean        | 1.94     |
# | time/                 |          |
# |    fps                | 259      |
# |    iterations         | 900      |
# |    time_elapsed       | 69       |
# |    total_timesteps    | 18000    |
# | train/                |          |
# |    entropy_loss       | -1.09    |
# |    explained_variance | 0.719    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | -0.0431  |
# |    value_loss         | 0.0394   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 304      |
# |    ep_rew_mean        | 2.02     |
# | time/                 |          |
# |    fps                | 253      |
# |    iterations         | 1000     |
# |    time_elapsed       | 79       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.938   |
# |    explained_variance | 0.806    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | 0.0972   |
# |    value_loss         | 0.0507   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 316      |
# |    ep_rew_mean        | 2.23     |
# | time/                 |          |
# |    fps                | 248      |
# |    iterations         | 1100     |
# |    time_elapsed       | 88       |
# |    total_timesteps    | 22000    |
# | train/                |          |
# |    entropy_loss       | -1.05    |
# |    explained_variance | 0.729    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | 0.142    |
# |    value_loss         | 0.0836   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 316      |
# |    ep_rew_mean        | 2.24     |
# | time/                 |          |
# |    fps                | 248      |
# |    iterations         | 1200     |
# |    time_elapsed       | 96       |
# |    total_timesteps    | 24000    |
# | train/                |          |
# |    entropy_loss       | -0.931   |
# |    explained_variance | 0.934    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | 0.0689   |
# |    value_loss         | 0.0247   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 323      |
# |    ep_rew_mean        | 2.36     |
# | time/                 |          |
# |    fps                | 248      |
# |    iterations         | 1300     |
# |    time_elapsed       | 104      |
# |    total_timesteps    | 26000    |
# | train/                |          |
# |    entropy_loss       | -1.06    |
# |    explained_variance | 0.979    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1299     |
# |    policy_loss        | 0.0452   |
# |    value_loss         | 0.0053   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 316      |
# |    ep_rew_mean        | 2.25     |
# | time/                 |          |
# |    fps                | 248      |
# |    iterations         | 1400     |
# |    time_elapsed       | 112      |
# |    total_timesteps    | 28000    |
# | train/                |          |
# |    entropy_loss       | -0.806   |
# |    explained_variance | 0.88     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1399     |
# |    policy_loss        | -0.0139  |
# |    value_loss         | 0.027    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 313      |
# |    ep_rew_mean        | 2.16     |
# | time/                 |          |
# |    fps                | 248      |
# |    iterations         | 1500     |
# |    time_elapsed       | 120      |
# |    total_timesteps    | 30000    |
# | train/                |          |
# |    entropy_loss       | -1.14    |
# |    explained_variance | 0.771    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1499     |
# |    policy_loss        | -0.0792  |
# |    value_loss         | 0.0378   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 307      |
# |    ep_rew_mean        | 2.07     |
# | time/                 |          |
# |    fps                | 246      |
# |    iterations         | 1600     |
# |    time_elapsed       | 129      |
# |    total_timesteps    | 32000    |
# | train/                |          |
# |    entropy_loss       | -1.16    |
# |    explained_variance | 0.966    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1599     |
# |    policy_loss        | 0.025    |
# |    value_loss         | 0.00888  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 308      |
# |    ep_rew_mean        | 2.09     |
# | time/                 |          |
# |    fps                | 244      |
# |    iterations         | 1700     |
# |    time_elapsed       | 138      |
# |    total_timesteps    | 34000    |
# | train/                |          |
# |    entropy_loss       | -0.915   |
# |    explained_variance | 0.875    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | -0.022   |
# |    value_loss         | 0.00803  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 309      |
# |    ep_rew_mean        | 2.12     |
# | time/                 |          |
# |    fps                | 243      |
# |    iterations         | 1800     |
# |    time_elapsed       | 147      |
# |    total_timesteps    | 36000    |
# | train/                |          |
# |    entropy_loss       | -1.08    |
# |    explained_variance | 0.918    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | 0.0336   |
# |    value_loss         | 0.0122   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 311      |
# |    ep_rew_mean        | 2.12     |
# | time/                 |          |
# |    fps                | 241      |
# |    iterations         | 1900     |
# |    time_elapsed       | 157      |
# |    total_timesteps    | 38000    |
# | train/                |          |
# |    entropy_loss       | -0.923   |
# |    explained_variance | 0.97     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | -0.0696  |
# |    value_loss         | 0.0182   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 319      |
# |    ep_rew_mean        | 2.23     |
# | time/                 |          |
# |    fps                | 240      |
# |    iterations         | 2000     |
# |    time_elapsed       | 166      |
# |    total_timesteps    | 40000    |
# | train/                |          |
# |    entropy_loss       | -0.727   |
# |    explained_variance | 0.172    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1999     |
# |    policy_loss        | 0.379    |
# |    value_loss         | 0.264    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 331      |
# |    ep_rew_mean        | 2.43     |
# | time/                 |          |
# |    fps                | 240      |
# |    iterations         | 2100     |
# |    time_elapsed       | 174      |
# |    total_timesteps    | 42000    |
# | train/                |          |
# |    entropy_loss       | -0.231   |
# |    explained_variance | 0.9      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2099     |
# |    policy_loss        | -0.0138  |
# |    value_loss         | 0.0532   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 350      |
# |    ep_rew_mean        | 2.85     |
# | time/                 |          |
# |    fps                | 240      |
# |    iterations         | 2200     |
# |    time_elapsed       | 183      |
# |    total_timesteps    | 44000    |
# | train/                |          |
# |    entropy_loss       | -0.468   |
# |    explained_variance | 0.929    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2199     |
# |    policy_loss        | -0.0653  |
# |    value_loss         | 0.0581   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 365      |
# |    ep_rew_mean        | 3.23     |
# | time/                 |          |
# |    fps                | 240      |
# |    iterations         | 2300     |
# |    time_elapsed       | 191      |
# |    total_timesteps    | 46000    |
# | train/                |          |
# |    entropy_loss       | -0.599   |
# |    explained_variance | -0.23    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2299     |
# |    policy_loss        | 0.0637   |
# |    value_loss         | 0.185    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 391      |
# |    ep_rew_mean        | 3.82     |
# | time/                 |          |
# |    fps                | 240      |
# |    iterations         | 2400     |
# |    time_elapsed       | 199      |
# |    total_timesteps    | 48000    |
# | train/                |          |
# |    entropy_loss       | -0.763   |
# |    explained_variance | 0.502    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2399     |
# |    policy_loss        | 0.0238   |
# |    value_loss         | 0.118    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 411      |
# |    ep_rew_mean        | 4.28     |
# | time/                 |          |
# |    fps                | 240      |
# |    iterations         | 2500     |
# |    time_elapsed       | 208      |
# |    total_timesteps    | 50000    |
# | train/                |          |
# |    entropy_loss       | -0.822   |
# |    explained_variance | 0.816    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2499     |
# |    policy_loss        | -0.0443  |
# |    value_loss         | 0.0587   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 413      |
# |    ep_rew_mean        | 4.42     |
# | time/                 |          |
# |    fps                | 239      |
# |    iterations         | 2600     |
# |    time_elapsed       | 217      |
# |    total_timesteps    | 52000    |
# | train/                |          |
# |    entropy_loss       | -0.547   |
# |    explained_variance | 0.888    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2599     |
# |    policy_loss        | 0.00284  |
# |    value_loss         | 0.128    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 409      |
# |    ep_rew_mean        | 4.46     |
# | time/                 |          |
# |    fps                | 239      |
# |    iterations         | 2700     |
# |    time_elapsed       | 225      |
# |    total_timesteps    | 54000    |
# | train/                |          |
# |    entropy_loss       | -0.836   |
# |    explained_variance | 0.888    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2699     |
# |    policy_loss        | 0.0174   |
# |    value_loss         | 0.0463   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 413      |
# |    ep_rew_mean        | 4.55     |
# | time/                 |          |
# |    fps                | 238      |
# |    iterations         | 2800     |
# |    time_elapsed       | 234      |
# |    total_timesteps    | 56000    |
# | train/                |          |
# |    entropy_loss       | -0.587   |
# |    explained_variance | 0.795    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2799     |
# |    policy_loss        | 0.102    |
# |    value_loss         | 0.166    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 410      |
# |    ep_rew_mean        | 4.55     |
# | time/                 |          |
# |    fps                | 238      |
# |    iterations         | 2900     |
# |    time_elapsed       | 243      |
# |    total_timesteps    | 58000    |
# | train/                |          |
# |    entropy_loss       | -0.624   |
# |    explained_variance | 0.719    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2899     |
# |    policy_loss        | 0.00827  |
# |    value_loss         | 0.0607   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 421      |
# |    ep_rew_mean        | 4.81     |
# | time/                 |          |
# |    fps                | 238      |
# |    iterations         | 3000     |
# |    time_elapsed       | 252      |
# |    total_timesteps    | 60000    |
# | train/                |          |
# |    entropy_loss       | -0.193   |
# |    explained_variance | 0.824    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2999     |
# |    policy_loss        | -0.0455  |
# |    value_loss         | 0.361    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 445      |
# |    ep_rew_mean        | 5.27     |
# | time/                 |          |
# |    fps                | 238      |
# |    iterations         | 3100     |
# |    time_elapsed       | 260      |
# |    total_timesteps    | 62000    |
# | train/                |          |
# |    entropy_loss       | -0.517   |
# |    explained_variance | 0.972    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3099     |
# |    policy_loss        | -0.123   |
# |    value_loss         | 0.0471   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 447      |
# |    ep_rew_mean        | 5.26     |
# | time/                 |          |
# |    fps                | 238      |
# |    iterations         | 3200     |
# |    time_elapsed       | 268      |
# |    total_timesteps    | 64000    |
# | train/                |          |
# |    entropy_loss       | -0.457   |
# |    explained_variance | 0.952    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3199     |
# |    policy_loss        | -0.0365  |
# |    value_loss         | 0.024    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 456      |
# |    ep_rew_mean        | 5.47     |
# | time/                 |          |
# |    fps                | 238      |
# |    iterations         | 3300     |
# |    time_elapsed       | 277      |
# |    total_timesteps    | 66000    |
# | train/                |          |
# |    entropy_loss       | -0.578   |
# |    explained_variance | 0.87     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3299     |
# |    policy_loss        | -0.151   |
# |    value_loss         | 0.1      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 461      |
# |    ep_rew_mean        | 5.55     |
# | time/                 |          |
# |    fps                | 238      |
# |    iterations         | 3400     |
# |    time_elapsed       | 285      |
# |    total_timesteps    | 68000    |
# | train/                |          |
# |    entropy_loss       | -0.772   |
# |    explained_variance | 0.95     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3399     |
# |    policy_loss        | 0.00344  |
# |    value_loss         | 0.0181   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 462      |
# |    ep_rew_mean        | 5.52     |
# | time/                 |          |
# |    fps                | 238      |
# |    iterations         | 3500     |
# |    time_elapsed       | 292      |
# |    total_timesteps    | 70000    |
# | train/                |          |
# |    entropy_loss       | -0.259   |
# |    explained_variance | 0.873    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3499     |
# |    policy_loss        | 0.0063   |
# |    value_loss         | 0.0816   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 453      |
# |    ep_rew_mean        | 5.3      |
# | time/                 |          |
# |    fps                | 239      |
# |    iterations         | 3600     |
# |    time_elapsed       | 300      |
# |    total_timesteps    | 72000    |
# | train/                |          |
# |    entropy_loss       | -0.663   |
# |    explained_variance | 0.765    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3599     |
# |    policy_loss        | -0.00496 |
# |    value_loss         | 0.129    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 456      |
# |    ep_rew_mean        | 5.29     |
# | time/                 |          |
# |    fps                | 240      |
# |    iterations         | 3700     |
# |    time_elapsed       | 308      |
# |    total_timesteps    | 74000    |
# | train/                |          |
# |    entropy_loss       | -0.41    |
# |    explained_variance | 0.959    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3699     |
# |    policy_loss        | 0.0122   |
# |    value_loss         | 0.0566   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 449      |
# |    ep_rew_mean        | 5.14     |
# | time/                 |          |
# |    fps                | 240      |
# |    iterations         | 3800     |
# |    time_elapsed       | 315      |
# |    total_timesteps    | 76000    |
# | train/                |          |
# |    entropy_loss       | -0.575   |
# |    explained_variance | 0.453    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3799     |
# |    policy_loss        | 0.0334   |
# |    value_loss         | 0.0613   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 455      |
# |    ep_rew_mean        | 5.26     |
# | time/                 |          |
# |    fps                | 241      |
# |    iterations         | 3900     |
# |    time_elapsed       | 322      |
# |    total_timesteps    | 78000    |
# | train/                |          |
# |    entropy_loss       | -0.555   |
# |    explained_variance | 0.919    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3899     |
# |    policy_loss        | -0.0128  |
# |    value_loss         | 0.0604   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 450      |
# |    ep_rew_mean        | 5.15     |
# | time/                 |          |
# |    fps                | 242      |
# |    iterations         | 4000     |
# |    time_elapsed       | 330      |
# |    total_timesteps    | 80000    |
# | train/                |          |
# |    entropy_loss       | -0.713   |
# |    explained_variance | 0.948    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3999     |
# |    policy_loss        | 0.113    |
# |    value_loss         | 0.0582   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 450      |
# |    ep_rew_mean        | 5.14     |
# | time/                 |          |
# |    fps                | 242      |
# |    iterations         | 4100     |
# |    time_elapsed       | 337      |
# |    total_timesteps    | 82000    |
# | train/                |          |
# |    entropy_loss       | -0.374   |
# |    explained_variance | 0.929    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4099     |
# |    policy_loss        | -0.184   |
# |    value_loss         | 0.111    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 451      |
# |    ep_rew_mean        | 5.23     |
# | time/                 |          |
# |    fps                | 243      |
# |    iterations         | 4200     |
# |    time_elapsed       | 345      |
# |    total_timesteps    | 84000    |
# | train/                |          |
# |    entropy_loss       | -0.44    |
# |    explained_variance | 0.963    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4199     |
# |    policy_loss        | -0.0283  |
# |    value_loss         | 0.045    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 455      |
# |    ep_rew_mean        | 5.31     |
# | time/                 |          |
# |    fps                | 243      |
# |    iterations         | 4300     |
# |    time_elapsed       | 352      |
# |    total_timesteps    | 86000    |
# | train/                |          |
# |    entropy_loss       | -0.704   |
# |    explained_variance | 0.913    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4299     |
# |    policy_loss        | -0.0826  |
# |    value_loss         | 0.0248   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 470      |
# |    ep_rew_mean        | 5.62     |
# | time/                 |          |
# |    fps                | 244      |
# |    iterations         | 4400     |
# |    time_elapsed       | 359      |
# |    total_timesteps    | 88000    |
# | train/                |          |
# |    entropy_loss       | -0.619   |
# |    explained_variance | 0.813    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4399     |
# |    policy_loss        | -0.116   |
# |    value_loss         | 0.102    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 484      |
# |    ep_rew_mean        | 5.9      |
# | time/                 |          |
# |    fps                | 245      |
# |    iterations         | 4500     |
# |    time_elapsed       | 367      |
# |    total_timesteps    | 90000    |
# | train/                |          |
# |    entropy_loss       | -0.206   |
# |    explained_variance | 0.884    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4499     |
# |    policy_loss        | 0.0325   |
# |    value_loss         | 0.148    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 508      |
# |    ep_rew_mean        | 6.39     |
# | time/                 |          |
# |    fps                | 245      |
# |    iterations         | 4600     |
# |    time_elapsed       | 374      |
# |    total_timesteps    | 92000    |
# | train/                |          |
# |    entropy_loss       | -0.446   |
# |    explained_variance | 0.943    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4599     |
# |    policy_loss        | -0.0175  |
# |    value_loss         | 0.047    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 516      |
# |    ep_rew_mean        | 6.53     |
# | time/                 |          |
# |    fps                | 246      |
# |    iterations         | 4700     |
# |    time_elapsed       | 382      |
# |    total_timesteps    | 94000    |
# | train/                |          |
# |    entropy_loss       | -0.412   |
# |    explained_variance | 0.854    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4699     |
# |    policy_loss        | -0.0031  |
# |    value_loss         | 0.0335   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 523      |
# |    ep_rew_mean        | 6.67     |
# | time/                 |          |
# |    fps                | 246      |
# |    iterations         | 4800     |
# |    time_elapsed       | 390      |
# |    total_timesteps    | 96000    |
# | train/                |          |
# |    entropy_loss       | -0.704   |
# |    explained_variance | 0.529    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4799     |
# |    policy_loss        | -0.0178  |
# |    value_loss         | 0.164    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 521      |
# |    ep_rew_mean        | 6.63     |
# | time/                 |          |
# |    fps                | 246      |
# |    iterations         | 4900     |
# |    time_elapsed       | 398      |
# |    total_timesteps    | 98000    |
# | train/                |          |
# |    entropy_loss       | -0.369   |
# |    explained_variance | 0.929    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4899     |
# |    policy_loss        | -0.0428  |
# |    value_loss         | 0.0588   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 517      |
# |    ep_rew_mean        | 6.59     |
# | time/                 |          |
# |    fps                | 245      |
# |    iterations         | 5000     |
# |    time_elapsed       | 406      |
# |    total_timesteps    | 100000   |
# | train/                |          |
# |    entropy_loss       | -0.333   |
# |    explained_variance | 0.94     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4999     |
# |    policy_loss        | -0.00779 |
# |    value_loss         | 0.0259   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 513      |
# |    ep_rew_mean        | 6.53     |
# | time/                 |          |
# |    fps                | 245      |
# |    iterations         | 5100     |
# |    time_elapsed       | 414      |
# |    total_timesteps    | 102000   |
# | train/                |          |
# |    entropy_loss       | -0.326   |
# |    explained_variance | 0.841    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5099     |
# |    policy_loss        | 0.0124   |
# |    value_loss         | 0.0367   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 514      |
# |    ep_rew_mean        | 6.52     |
# | time/                 |          |
# |    fps                | 245      |
# |    iterations         | 5200     |
# |    time_elapsed       | 423      |
# |    total_timesteps    | 104000   |
# | train/                |          |
# |    entropy_loss       | -0.321   |
# |    explained_variance | 0.713    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5199     |
# |    policy_loss        | 0.0569   |
# |    value_loss         | 0.184    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 521      |
# |    ep_rew_mean        | 6.67     |
# | time/                 |          |
# |    fps                | 245      |
# |    iterations         | 5300     |
# |    time_elapsed       | 431      |
# |    total_timesteps    | 106000   |
# | train/                |          |
# |    entropy_loss       | -0.427   |
# |    explained_variance | 0.86     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5299     |
# |    policy_loss        | 0.0798   |
# |    value_loss         | 0.0599   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 518      |
# |    ep_rew_mean        | 6.6      |
# | time/                 |          |
# |    fps                | 245      |
# |    iterations         | 5400     |
# |    time_elapsed       | 440      |
# |    total_timesteps    | 108000   |
# | train/                |          |
# |    entropy_loss       | -0.203   |
# |    explained_variance | 0.743    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5399     |
# |    policy_loss        | -0.0176  |
# |    value_loss         | 0.0925   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 521      |
# |    ep_rew_mean        | 6.62     |
# | time/                 |          |
# |    fps                | 244      |
# |    iterations         | 5500     |
# |    time_elapsed       | 449      |
# |    total_timesteps    | 110000   |
# | train/                |          |
# |    entropy_loss       | -0.435   |
# |    explained_variance | 0.983    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5499     |
# |    policy_loss        | 0.00644  |
# |    value_loss         | 0.0518   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 524      |
# |    ep_rew_mean        | 6.78     |
# | time/                 |          |
# |    fps                | 244      |
# |    iterations         | 5600     |
# |    time_elapsed       | 458      |
# |    total_timesteps    | 112000   |
# | train/                |          |
# |    entropy_loss       | -0.369   |
# |    explained_variance | 0.881    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5599     |
# |    policy_loss        | -0.0614  |
# |    value_loss         | 0.0255   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 527      |
# |    ep_rew_mean        | 6.8      |
# | time/                 |          |
# |    fps                | 244      |
# |    iterations         | 5700     |
# |    time_elapsed       | 466      |
# |    total_timesteps    | 114000   |
# | train/                |          |
# |    entropy_loss       | -0.283   |
# |    explained_variance | 0.413    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5699     |
# |    policy_loss        | 0.0375   |
# |    value_loss         | 0.0814   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 539      |
# |    ep_rew_mean        | 7.12     |
# | time/                 |          |
# |    fps                | 244      |
# |    iterations         | 5800     |
# |    time_elapsed       | 474      |
# |    total_timesteps    | 116000   |
# | train/                |          |
# |    entropy_loss       | -0.318   |
# |    explained_variance | 0.318    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5799     |
# |    policy_loss        | -0.0429  |
# |    value_loss         | 0.285    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 542      |
# |    ep_rew_mean        | 7.21     |
# | time/                 |          |
# |    fps                | 244      |
# |    iterations         | 5900     |
# |    time_elapsed       | 482      |
# |    total_timesteps    | 118000   |
# | train/                |          |
# |    entropy_loss       | -0.519   |
# |    explained_variance | 0.821    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5899     |
# |    policy_loss        | 0.0224   |
# |    value_loss         | 0.0798   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 545      |
# |    ep_rew_mean        | 7.31     |
# | time/                 |          |
# |    fps                | 244      |
# |    iterations         | 6000     |
# |    time_elapsed       | 489      |
# |    total_timesteps    | 120000   |
# | train/                |          |
# |    entropy_loss       | -0.34    |
# |    explained_variance | 0.812    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5999     |
# |    policy_loss        | -0.132   |
# |    value_loss         | 0.0923   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 546      |
# |    ep_rew_mean        | 7.32     |
# | time/                 |          |
# |    fps                | 245      |
# |    iterations         | 6100     |
# |    time_elapsed       | 497      |
# |    total_timesteps    | 122000   |
# | train/                |          |
# |    entropy_loss       | -0.283   |
# |    explained_variance | 0.936    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6099     |
# |    policy_loss        | -0.057   |
# |    value_loss         | 0.0949   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 543      |
# |    ep_rew_mean        | 7.24     |
# | time/                 |          |
# |    fps                | 245      |
# |    iterations         | 6200     |
# |    time_elapsed       | 505      |
# |    total_timesteps    | 124000   |
# | train/                |          |
# |    entropy_loss       | -0.468   |
# |    explained_variance | 0.949    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6199     |
# |    policy_loss        | -0.00269 |
# |    value_loss         | 0.00628  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 555      |
# |    ep_rew_mean        | 7.5      |
# | time/                 |          |
# |    fps                | 245      |
# |    iterations         | 6300     |
# |    time_elapsed       | 512      |
# |    total_timesteps    | 126000   |
# | train/                |          |
# |    entropy_loss       | -0.338   |
# |    explained_variance | -0.92    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6299     |
# |    policy_loss        | 0.0603   |
# |    value_loss         | 0.487    |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 546       |
# |    ep_rew_mean        | 7.34      |
# | time/                 |           |
# |    fps                | 246       |
# |    iterations         | 6400      |
# |    time_elapsed       | 519       |
# |    total_timesteps    | 128000    |
# | train/                |           |
# |    entropy_loss       | -0.244    |
# |    explained_variance | 0.797     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6399      |
# |    policy_loss        | -0.000641 |
# |    value_loss         | 0.0736    |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 554      |
# |    ep_rew_mean        | 7.52     |
# | time/                 |          |
# |    fps                | 246      |
# |    iterations         | 6500     |
# |    time_elapsed       | 527      |
# |    total_timesteps    | 130000   |
# | train/                |          |
# |    entropy_loss       | -0.217   |
# |    explained_variance | 0.968    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6499     |
# |    policy_loss        | -0.0842  |
# |    value_loss         | 0.0881   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 553      |
# |    ep_rew_mean        | 7.44     |
# | time/                 |          |
# |    fps                | 246      |
# |    iterations         | 6600     |
# |    time_elapsed       | 534      |
# |    total_timesteps    | 132000   |
# | train/                |          |
# |    entropy_loss       | -0.0995  |
# |    explained_variance | 0.917    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6599     |
# |    policy_loss        | -0.00199 |
# |    value_loss         | 0.051    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 557      |
# |    ep_rew_mean        | 7.49     |
# | time/                 |          |
# |    fps                | 247      |
# |    iterations         | 6700     |
# |    time_elapsed       | 542      |
# |    total_timesteps    | 134000   |
# | train/                |          |
# |    entropy_loss       | -0.444   |
# |    explained_variance | 0.967    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6699     |
# |    policy_loss        | 0.0518   |
# |    value_loss         | 0.0317   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 575      |
# |    ep_rew_mean        | 7.82     |
# | time/                 |          |
# |    fps                | 247      |
# |    iterations         | 6800     |
# |    time_elapsed       | 550      |
# |    total_timesteps    | 136000   |
# | train/                |          |
# |    entropy_loss       | -0.0811  |
# |    explained_variance | 0.266    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6799     |
# |    policy_loss        | 0.0608   |
# |    value_loss         | 0.447    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 576      |
# |    ep_rew_mean        | 7.76     |
# | time/                 |          |
# |    fps                | 247      |
# |    iterations         | 6900     |
# |    time_elapsed       | 557      |
# |    total_timesteps    | 138000   |
# | train/                |          |
# |    entropy_loss       | -0.188   |
# |    explained_variance | 0.882    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6899     |
# |    policy_loss        | 0.0463   |
# |    value_loss         | 0.118    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 579      |
# |    ep_rew_mean        | 7.75     |
# | time/                 |          |
# |    fps                | 247      |
# |    iterations         | 7000     |
# |    time_elapsed       | 565      |
# |    total_timesteps    | 140000   |
# | train/                |          |
# |    entropy_loss       | -0.205   |
# |    explained_variance | 0.493    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6999     |
# |    policy_loss        | 0.00347  |
# |    value_loss         | 0.12     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 580      |
# |    ep_rew_mean        | 7.78     |
# | time/                 |          |
# |    fps                | 247      |
# |    iterations         | 7100     |
# |    time_elapsed       | 573      |
# |    total_timesteps    | 142000   |
# | train/                |          |
# |    entropy_loss       | -0.131   |
# |    explained_variance | 0.91     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7099     |
# |    policy_loss        | 0.0114   |
# |    value_loss         | 0.0493   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 580      |
# |    ep_rew_mean        | 7.74     |
# | time/                 |          |
# |    fps                | 247      |
# |    iterations         | 7200     |
# |    time_elapsed       | 580      |
# |    total_timesteps    | 144000   |
# | train/                |          |
# |    entropy_loss       | -0.15    |
# |    explained_variance | 0.84     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7199     |
# |    policy_loss        | -0.00973 |
# |    value_loss         | 0.0783   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 590      |
# |    ep_rew_mean        | 8.01     |
# | time/                 |          |
# |    fps                | 248      |
# |    iterations         | 7300     |
# |    time_elapsed       | 588      |
# |    total_timesteps    | 146000   |
# | train/                |          |
# |    entropy_loss       | -0.136   |
# |    explained_variance | 0.46     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7299     |
# |    policy_loss        | 0.0203   |
# |    value_loss         | 0.155    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 581      |
# |    ep_rew_mean        | 7.85     |
# | time/                 |          |
# |    fps                | 248      |
# |    iterations         | 7400     |
# |    time_elapsed       | 596      |
# |    total_timesteps    | 148000   |
# | train/                |          |
# |    entropy_loss       | -0.116   |
# |    explained_variance | 0.954    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7399     |
# |    policy_loss        | -0.167   |
# |    value_loss         | 0.067    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 569      |
# |    ep_rew_mean        | 7.63     |
# | time/                 |          |
# |    fps                | 248      |
# |    iterations         | 7500     |
# |    time_elapsed       | 604      |
# |    total_timesteps    | 150000   |
# | train/                |          |
# |    entropy_loss       | -0.175   |
# |    explained_variance | 0.838    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7499     |
# |    policy_loss        | -0.00293 |
# |    value_loss         | 0.0344   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 572      |
# |    ep_rew_mean        | 7.63     |
# | time/                 |          |
# |    fps                | 248      |
# |    iterations         | 7600     |
# |    time_elapsed       | 611      |
# |    total_timesteps    | 152000   |
# | train/                |          |
# |    entropy_loss       | -0.278   |
# |    explained_variance | 0.802    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7599     |
# |    policy_loss        | -0.0328  |
# |    value_loss         | 0.0624   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 565      |
# |    ep_rew_mean        | 7.56     |
# ...
# |    explained_variance | 0.729    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 17499    |
# |    policy_loss        | -0.00905 |
# |    value_loss         | 0.197    |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 10.6      |
# | time/                 |           |
# |    fps                | 236       |
# |    iterations         | 17600     |
# |    time_elapsed       | 1489      |
# |    total_timesteps    | 352000    |
# | train/                |           |
# |    entropy_loss       | -0.056    |
# |    explained_variance | 0.79      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 17599     |
# |    policy_loss        | -0.000928 |
# |    value_loss         | 0.134     |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 694      |
# |    ep_rew_mean        | 10.7     |
# | time/                 |          |
# |    fps                | 236      |
# |    iterations         | 17700    |
# |    time_elapsed       | 1497     |
# |    total_timesteps    | 354000   |
# | train/                |          |
# |    entropy_loss       | -0.006   |
# |    explained_variance | 0.923    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 17699    |
# |    policy_loss        | 0.000261 |
# |    value_loss         | 0.0594   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 688      |
# |    ep_rew_mean        | 10.6     |
# | time/                 |          |
# |    fps                | 236      |
# |    iterations         | 17800    |
# |    time_elapsed       | 1505     |
# |    total_timesteps    | 356000   |
# | train/                |          |
# |    entropy_loss       | -0.281   |
# |    explained_variance | 0.966    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 17799    |
# |    policy_loss        | 0.0424   |
# |    value_loss         | 0.0267   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 682      |
# |    ep_rew_mean        | 10.4     |
# | time/                 |          |
# |    fps                | 236      |
# |    iterations         | 17900    |
# |    time_elapsed       | 1514     |
# |    total_timesteps    | 358000   |
# | train/                |          |
# |    entropy_loss       | -0.0932  |
# |    explained_variance | 0.845    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 17899    |
# |    policy_loss        | 0.00569  |
# |    value_loss         | 0.0519   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 686      |
# |    ep_rew_mean        | 10.6     |
# | time/                 |          |
# |    fps                | 236      |
# |    iterations         | 18000    |
# |    time_elapsed       | 1522     |
# |    total_timesteps    | 360000   |
# | train/                |          |
# |    entropy_loss       | -0.165   |
# |    explained_variance | 0.746    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 17999    |
# |    policy_loss        | -0.00466 |
# |    value_loss         | 0.0458   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 679      |
# |    ep_rew_mean        | 10.3     |
# | time/                 |          |
# |    fps                | 236      |
# |    iterations         | 18100    |
# |    time_elapsed       | 1530     |
# |    total_timesteps    | 362000   |
# | train/                |          |
# |    entropy_loss       | -0.133   |
# |    explained_variance | 0.596    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18099    |
# |    policy_loss        | 0.014    |
# |    value_loss         | 0.118    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 673      |
# |    ep_rew_mean        | 10.2     |
# | time/                 |          |
# |    fps                | 236      |
# |    iterations         | 18200    |
# |    time_elapsed       | 1539     |
# |    total_timesteps    | 364000   |
# | train/                |          |
# |    entropy_loss       | -0.0749  |
# |    explained_variance | -0.085   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18199    |
# |    policy_loss        | 0.211    |
# |    value_loss         | 0.187    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 672      |
# |    ep_rew_mean        | 10.3     |
# | time/                 |          |
# |    fps                | 236      |
# |    iterations         | 18300    |
# |    time_elapsed       | 1547     |
# |    total_timesteps    | 366000   |
# | train/                |          |
# |    entropy_loss       | -0.189   |
# |    explained_variance | 0.917    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18299    |
# |    policy_loss        | -0.0112  |
# |    value_loss         | 0.193    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 656      |
# |    ep_rew_mean        | 9.97     |
# | time/                 |          |
# |    fps                | 236      |
# |    iterations         | 18400    |
# |    time_elapsed       | 1555     |
# |    total_timesteps    | 368000   |
# | train/                |          |
# |    entropy_loss       | -0.00861 |
# |    explained_variance | 0.777    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18399    |
# |    policy_loss        | 0.000538 |
# |    value_loss         | 0.0852   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 649      |
# |    ep_rew_mean        | 9.72     |
# | time/                 |          |
# |    fps                | 236      |
# |    iterations         | 18500    |
# |    time_elapsed       | 1564     |
# |    total_timesteps    | 370000   |
# | train/                |          |
# |    entropy_loss       | -0.178   |
# |    explained_variance | 0.942    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18499    |
# |    policy_loss        | 0.00946  |
# |    value_loss         | 0.105    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 653      |
# |    ep_rew_mean        | 9.77     |
# | time/                 |          |
# |    fps                | 236      |
# |    iterations         | 18600    |
# |    time_elapsed       | 1571     |
# |    total_timesteps    | 372000   |
# | train/                |          |
# |    entropy_loss       | -0.266   |
# |    explained_variance | 0.387    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18599    |
# |    policy_loss        | -0.0128  |
# |    value_loss         | 0.126    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 667      |
# |    ep_rew_mean        | 10       |
# | time/                 |          |
# |    fps                | 236      |
# |    iterations         | 18700    |
# |    time_elapsed       | 1579     |
# |    total_timesteps    | 374000   |
# | train/                |          |
# |    entropy_loss       | -0.0285  |
# |    explained_variance | 0.681    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18699    |
# |    policy_loss        | 0.00232  |
# |    value_loss         | 0.224    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 669      |
# |    ep_rew_mean        | 10       |
# | time/                 |          |
# |    fps                | 236      |
# |    iterations         | 18800    |
# |    time_elapsed       | 1588     |
# |    total_timesteps    | 376000   |
# | train/                |          |
# |    entropy_loss       | -0.168   |
# |    explained_variance | 0.72     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18799    |
# |    policy_loss        | -0.00717 |
# |    value_loss         | 0.205    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 683      |
# |    ep_rew_mean        | 10.5     |
# | time/                 |          |
# |    fps                | 236      |
# |    iterations         | 18900    |
# |    time_elapsed       | 1596     |
# |    total_timesteps    | 378000   |
# | train/                |          |
# |    entropy_loss       | -0.228   |
# |    explained_variance | 0.729    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18899    |
# |    policy_loss        | -0.123   |
# |    value_loss         | 0.465    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 686      |
# |    ep_rew_mean        | 10.6     |
# | time/                 |          |
# |    fps                | 236      |
# |    iterations         | 19000    |
# |    time_elapsed       | 1604     |
# |    total_timesteps    | 380000   |
# | train/                |          |
# |    entropy_loss       | -0.216   |
# |    explained_variance | 0.7      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18999    |
# |    policy_loss        | -0.123   |
# |    value_loss         | 0.215    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 685      |
# |    ep_rew_mean        | 10.7     |
# | time/                 |          |
# |    fps                | 236      |
# |    iterations         | 19100    |
# |    time_elapsed       | 1612     |
# |    total_timesteps    | 382000   |
# | train/                |          |
# |    entropy_loss       | -0.178   |
# |    explained_variance | 0.95     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19099    |
# |    policy_loss        | 0.000358 |
# |    value_loss         | 0.0526   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 701      |
# |    ep_rew_mean        | 11       |
# | time/                 |          |
# |    fps                | 236      |
# |    iterations         | 19200    |
# |    time_elapsed       | 1621     |
# |    total_timesteps    | 384000   |
# | train/                |          |
# |    entropy_loss       | -0.0904  |
# |    explained_variance | 0.858    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19199    |
# |    policy_loss        | -0.00835 |
# |    value_loss         | 0.122    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 703      |
# |    ep_rew_mean        | 11.1     |
# | time/                 |          |
# |    fps                | 236      |
# |    iterations         | 19300    |
# |    time_elapsed       | 1629     |
# |    total_timesteps    | 386000   |
# | train/                |          |
# |    entropy_loss       | -0.0536  |
# |    explained_variance | 0.903    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19299    |
# |    policy_loss        | 0.00461  |
# |    value_loss         | 0.112    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 706      |
# |    ep_rew_mean        | 11.2     |
# | time/                 |          |
# |    fps                | 236      |
# |    iterations         | 19400    |
# |    time_elapsed       | 1638     |
# |    total_timesteps    | 388000   |
# | train/                |          |
# |    entropy_loss       | -0.292   |
# |    explained_variance | 0.884    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19399    |
# |    policy_loss        | 0.00978  |
# |    value_loss         | 0.0683   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 711      |
# |    ep_rew_mean        | 11.3     |
# | time/                 |          |
# |    fps                | 236      |
# |    iterations         | 19500    |
# |    time_elapsed       | 1646     |
# |    total_timesteps    | 390000   |
# | train/                |          |
# |    entropy_loss       | -0.15    |
# |    explained_variance | 0.936    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19499    |
# |    policy_loss        | 0.0299   |
# |    value_loss         | 0.0579   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 715      |
# |    ep_rew_mean        | 11.4     |
# | time/                 |          |
# |    fps                | 236      |
# |    iterations         | 19600    |
# |    time_elapsed       | 1654     |
# |    total_timesteps    | 392000   |
# | train/                |          |
# |    entropy_loss       | -0.268   |
# |    explained_variance | 0.865    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19599    |
# |    policy_loss        | 0.00437  |
# |    value_loss         | 0.0256   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 710      |
# |    ep_rew_mean        | 11.4     |
# | time/                 |          |
# |    fps                | 236      |
# |    iterations         | 19700    |
# |    time_elapsed       | 1662     |
# |    total_timesteps    | 394000   |
# | train/                |          |
# |    entropy_loss       | -0.136   |
# |    explained_variance | 0.842    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19699    |
# |    policy_loss        | -0.0419  |
# |    value_loss         | 0.079    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 721      |
# |    ep_rew_mean        | 11.6     |
# | time/                 |          |
# |    fps                | 236      |
# |    iterations         | 19800    |
# |    time_elapsed       | 1671     |
# |    total_timesteps    | 396000   |
# | train/                |          |
# |    entropy_loss       | -0.137   |
# |    explained_variance | 0.597    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19799    |
# |    policy_loss        | 0.0202   |
# |    value_loss         | 0.172    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 722      |
# |    ep_rew_mean        | 11.5     |
# | time/                 |          |
# |    fps                | 236      |
# |    iterations         | 19900    |
# |    time_elapsed       | 1679     |
# |    total_timesteps    | 398000   |
# | train/                |          |
# |    entropy_loss       | -0.0579  |
# |    explained_variance | 0.755    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19899    |
# |    policy_loss        | 0.0011   |
# |    value_loss         | 0.315    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 714      |
# |    ep_rew_mean        | 11.3     |
# | time/                 |          |
# |    fps                | 237      |
# |    iterations         | 20000    |
# |    time_elapsed       | 1687     |
# |    total_timesteps    | 400000   |
# | train/                |          |
# |    entropy_loss       | -0.0802  |
# |    explained_variance | 0.772    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19999    |
# |    policy_loss        | 0.00619  |
# |    value_loss         | 0.107    |
# ------------------------------------

# %% [markdown]
# # 4. Save and Reload Model

# %%
a2c_path = os.path.join('Training', 'Saved Models', 'A2C_model')

# %%
model.save(a2c_path)

# %%
del model

# %%
env = make_atari_env('Breakout-v0', n_envs=1, seed=0)
env = VecFrameStack(env, n_stack=4)

# %%
model = A2C.load(a2c_path, env)
# Out:
# Wrapping the env in a VecTransposeImage.

# %% [markdown]
# # 5. Evaluate and Test

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)
# Out:
# 2022-09-11 22:20:58.668 python[84410:35101667] Warning: Expected min height of view: (<NSPopoverTouchBarItemButton: 0x7fb794c1b090>) to be less than or equal to 30 but got a height of 32.000000. This error will be logged once per view in violation.
# 2022-09-11 22:20:58.669 python[84410:35101667] Warning: Expected min height of view: (<NSButton: 0x7fb79387dc70>) to be less than or equal to 30 but got a height of 32.000000. This error will be logged once per view in violation.
# 2022-09-11 22:20:58.671 python[84410:35101667] Warning: Expected min height of view: (<NSPopoverTouchBarItemButton: 0x7fb79387e090>) to be less than or equal to 30 but got a height of 32.000000. This error will be logged once per view in violation.
# 2022-09-11 22:20:58.673 python[84410:35101667] Warning: Expected min height of view: (<NSPopoverTouchBarItemButton: 0x7fb79387e6d0>) to be less than or equal to 30 but got a height of 32.000000. This error will be logged once per view in violation.
# (12.9, 5.127377497317708)

# %%
obs = env.reset()
while True:
    action, _states = model.predict(obs)
    obs, rewards, dones, info = env.step(action)
    env.render()

# %%
env.close()
